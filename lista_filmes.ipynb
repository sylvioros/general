# %%
import pandas as pd
# !pip install xlrd
# Out:
# ...
# WARNING: You are using pip version 19.3.1; however, version 20.0.2 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
filmes = pd.read_excel('2018_2019.xlsx', index_col=0)
filmes = filmes.sort_values('Your Rating', ascending=False)

# %%
pd.set_option('display.max_rows', 300)
filmes
# Out:
#                                                 IMDb Rating  Year  Your Rating
# Title
# Doctor Sleep                                            7.4  2019           10
# Life Itself                                             6.8  2018           10
# Green Book                                              8.2  2018           10
# Wonder                                                  8.0  2017           10
# Demain tout commence                                    7.4  2016           10
# Hidden Figures                                          7.8  2016           10
# Sidney Hall                                             6.9  2017            9
# Searching                                               7.6  2018            9
# Paul, Apostle of Christ                                 6.6  2018            9
# The Glass Castle                                        7.1  2017            9
# Charlie and the Chocolate Factory                       6.6  2005            9
# ...
